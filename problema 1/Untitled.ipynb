# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random
import math

df = pd.read_csv('1.csv')

df[ df['Caso']=='r4'].plot.scatter(x='Trabajos', y='Ticks', color='Yellow', label='Random, k=10^4')
df[ df['Caso']=='r8'].plot.scatter(x='Trabajos', y='Ticks', color='Red', label='Random, k=10^8')



ax=df[ df['Caso']=='Random2'].plot.scatter(x='Trabajos', y='Ticks', color='Blue', label='Random')
df[ df['Caso']=='r4'].plot.scatter(x='Trabajos', y='Ticks', ax=ax, color='Yellow', label='Random, k=10^4')
df[ df['Caso']=='r8'].plot.scatter(x='Trabajos', y='Ticks', ax=ax, color='Red', label='Random, k=10^8')




plt.ylabel('Segundos')
plt.xlabel('Trabajos')
plt.xlim(0,1100)
plt.ylim(0,7)
plt.show()
