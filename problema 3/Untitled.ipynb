# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random
import math

df2 = pd.read_csv('instanciasRandom2.csv', ' ')

df2.plot.scatter(x='clientes', y='tiempo', color='Blue', label='Random')

plt.ylabel('Ticks')
plt.xlabel('Clientes')
plt.show()

df2['tiempo']=(df2['tiempo']/df2['clientes'])/df2['clientes']

df2.plot.scatter(x='clientes', y='tiempo', color='Blue', label='Random')

plt.ylabel('Ticks')
plt.xlabel('Clientes')
plt.show()

df2.plot.scatter(x='clientes', y='tiempo', color='Blue', label='Random')

plt.ylabel('Ticks')
plt.xlim(20,60)
plt.xlabel('Clientes')
plt.show()

# %%
df3 = pd.read_csv('randomCHEBAR2.csv', ' ')
df4 = pd.read_csv('mejorchebar.csv', ' ')
df5 = pd.read_csv('peorcaso2.csv', ' ')

ax = df3.plot.scatter(x='clientes', y='tiempo', color='Blue', label='Random')
#df4.plot.scatter(x='clientes', y='tiempo', color='Green',ax=ax, label='Mejor')
#df5.plot.scatter(x='clientes', y='tiempo', color='Red',ax=ax, label='Peor')

plt.ylabel('Ticks')
plt.xlabel('clientes')
plt.ylim(0,6000)
plt.show()

# %%
ax= df3[df3['fabricas']==df3['clientes']-1].plot.scatter(x='clientes', y='tiempo', color='Blue', label='fabricas=clientes-1')
df3[df3['fabricas']==df3['clientes']-10].plot.scatter(x='clientes', y='tiempo', color='Red', ax=ax, label='fabricas=clientes-10')

df3[df3['fabricas']==df3['clientes']-20].plot.scatter(x='clientes', y='tiempo', color='Green', ax=ax, label='fabricas=clientes-20')
df3[df3['fabricas']==df3['clientes']-30].plot.scatter(x='clientes', y='tiempo', color='Yellow', ax=ax, label='fabricas=clientes-30')
df3[df3['fabricas']==df3['clientes']-40].plot.scatter(x='clientes', y='tiempo', color='Violet', ax=ax, label='fabricas=clientes-40')
df3[df3['fabricas']==df3['clientes']-50].plot.scatter(x='clientes', y='tiempo', color='Brown', ax=ax, label='fabricas=clientes-50')

plt.ylabel('Ticks')
plt.xlabel('clientes')
plt.ylim(0,6000)
plt.show()

# %%
ax= df3[df3['fabricas']==df3['clientes']-1][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Blue', label='fabricas=clientes-1')
df3[df3['fabricas']==df3['clientes']-10][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Red', ax=ax, label='fabricas=clientes-10')
df3[df3['fabricas']==df3['clientes']-20][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Green', ax=ax, label='fabricas=clientes-20')
df3[df3['fabricas']==df3['clientes']-30][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Yellow', ax=ax, label='fabricas=clientes-30')
df3[df3['fabricas']==df3['clientes']-40][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Violet', ax=ax, label='fabricas=clientes-40')
df3[df3['fabricas']==df3['clientes']-50][df3['clientes']==60].plot(x='rutas', y='tiempo', color='Brown', ax=ax, label='fabricas=clientes-50')


plt.title('Clientes=60')
plt.ylabel('Ticks')
plt.xlabel('rutas')
plt.show()

ax= df3[df3['fabricas']==df3['clientes']-1][df3['clientes']==50].plot(x='rutas', y='tiempo', color='Blue', label='fabricas=clientes-1')
df3[df3['fabricas']==df3['clientes']-10][df3['clientes']==50].plot(x='rutas', y='tiempo', color='Red', ax=ax, label='fabricas=clientes-10')
df3[df3['fabricas']==df3['clientes']-20][df3['clientes']==50].plot(x='rutas', y='tiempo', color='Green', ax=ax, label='fabricas=clientes-20')
df3[df3['fabricas']==df3['clientes']-30][df3['clientes']==50].plot(x='rutas', y='tiempo', color='Yellow', ax=ax, label='fabricas=clientes-30')
df3[df3['fabricas']==df3['clientes']-40][df3['clientes']==50].plot(x='rutas', y='tiempo', color='Violet', ax=ax, label='fabricas=clientes-40')
#df3[df3['fabricas']==df3['clientes']-50][df3['clientes']==50].plot.scatter(x='rutas', y='tiempo', color='Brown', ax=ax, label='fabricas=clientes-50')


plt.title('Clientes=50')
plt.ylabel('Ticks')
plt.xlabel('rutas')
plt.show()

ax= df3[df3['fabricas']==df3['clientes']-1][df3['clientes']==40].plot(x='rutas', y='tiempo', color='Blue', label='fabricas=clientes-1')
df3[df3['fabricas']==df3['clientes']-10][df3['clientes']==40].plot(x='rutas', y='tiempo', color='Red', ax=ax, label='fabricas=clientes-10')
df3[df3['fabricas']==df3['clientes']-20][df3['clientes']==40].plot(x='rutas', y='tiempo', color='Green', ax=ax, label='fabricas=clientes-20')
df3[df3['fabricas']==df3['clientes']-30][df3['clientes']==40].plot(x='rutas', y='tiempo', color='Yellow', ax=ax, label='fabricas=clientes-30')
#df3[df3['fabricas']==df3['clientes']-40][df3['clientes']==40].plot.scatter(x='rutas', y='tiempo', color='Violet', ax=ax, label='fabricas=clientes-40')
#df3[df3['fabricas']==df3['clientes']-50][df3['clientes']==50].plot.scatter(x='rutas', y='tiempo', color='Brown', ax=ax, label='fabricas=clientes-50')


plt.title('Clientes=40')
plt.ylabel('Ticks')
plt.xlabel('rutas')
plt.show()

ax= df3[df3['fabricas']==df3['clientes']-1][df3['clientes']==30].plot.scatter(x='rutas', y='tiempo', color='Blue', label='fabricas=clientes-1')
df3[df3['fabricas']==df3['clientes']-10][df3['clientes']==30].plot.scatter(x='rutas', y='tiempo', color='Red', ax=ax, label='fabricas=clientes-10')
df3[df3['fabricas']==df3['clientes']-20][df3['clientes']==30].plot.scatter(x='rutas', y='tiempo', color='Green', ax=ax, label='fabricas=clientes-20')
#df3[df3['fabricas']==df3['clientes']-30][df3['clientes']==50].plot.scatter(x='rutas', y='tiempo', color='Yellow', ax=ax, label='fabricas=clientes-30')
#df3[df3['fabricas']==df3['clientes']-40][df3['clientes']==50].plot.scatter(x='rutas', y='tiempo', color='Violet', ax=ax, label='fabricas=clientes-40')
#df3[df3['fabricas']==df3['clientes']-50][df3['clientes']==50].plot.scatter(x='rutas', y='tiempo', color='Brown', ax=ax, label='fabricas=clientes-50')


plt.title('Clientes=30')
plt.ylabel('Ticks')
plt.xlabel('rutas')
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# ...
